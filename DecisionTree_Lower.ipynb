# %% [markdown]
# # Predict Regulation Throughput Ratio with CART Decision Trees
# ## (Lower Frequency Regulation Service)

# %% [markdown]
# ## 1. Import the necessary modules and libraries

# %%
# data analysis and wrangling
import pandas as pd
import numpy as np

# visualization
import matplotlib.pyplot as plt

# machine learning
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV
from sklearn import tree

# %% [markdown]
# ## 2. Exploring and Preprocessing the Data

# %%
# read data from csv file
df = pd.read_csv("df_lower_alldata.csv").fillna(0)

# %%
df = df.drop(['Unnamed: 0', 'Interval Ending (AEST)'],axis=1)
df.head(5)
# Out:
#    BLUFF1  CLEMGPWF  HALLWF1  HALLWF2  HDWF1  HDWF2  HDWF3  LKBONNY2  \
# 0    14.3   2.44919    13.60    10.63   22.2   15.6   16.6  32.53022
# 1     9.9   1.51274     8.72     7.63   19.6   17.0   13.1  23.63865
# 2    11.0   0.79239     9.27     7.26   14.6   16.0   12.0  22.36064
# 3     4.7   1.65681     6.49    -0.06   10.7   21.9   16.2  26.73126
# 4     3.7   0.72035     5.34    -0.36   13.0   22.6   22.0  25.91605
#
#    LKBONNY3  NBHWF1  SNOWNTH1  SNOWSTH1  SNOWTWN1  WATERLWF  Unnamed: 15  \
# 0  13.22982    21.5      13.4       7.4  12.43428      13.3          0.0
# 1   9.43392     9.3       9.7       1.2   6.01231       8.9          0.0
# 2   5.13563     9.1       8.9       2.3   4.41001       4.1          0.0
# 3   6.47535    12.0      11.4       7.3   8.23130       0.2          0.0
# 4   7.81508     7.3      12.3       6.4   6.92434      -0.4          0.0
#
#    Average Frequency (Hz)  Median Frequency (Hz)  Cummulative Frequency (Hz)  \
# 0               50.063867              50.070000                    2.340012
# 1               50.043700              50.040001                    1.950005
# 2               50.047967              50.040001                    2.269928
# 3               50.032533              50.029999                    2.140041
# 4               50.029000              50.029999                    2.140018
#
#    Difference Frequency (Hz)  Lower Throughput Ratio
# 0                   0.000000                0.020234
# 1                   0.010002                0.126083
# 2                   0.050003                0.090646
# 3                   0.020000                0.181213
# 4                  -0.060001                0.106281

# %%
df.describe()
# Out:
#              BLUFF1      CLEMGPWF       HALLWF1       HALLWF2         HDWF1  \
# count  20778.000000  20778.000000  20778.000000  20778.000000  20778.000000
# mean      19.203651     23.186787     40.469118     30.710160     48.014205
# std       17.072084     18.295492     29.090983     22.213073     32.042073
# min       -0.200000     -0.648320     -0.840000     -0.600000     -1.100000
# 25%        2.700000      5.258560     13.083750      9.910000     17.312500
# 50%       14.690500     21.290000     39.225000     29.658000     48.700000
# 75%       36.275108     40.483680     68.280000     51.390000     76.400000
# max       52.962000     56.415000     90.670000     70.360000    100.800000
#
#               HDWF2         HDWF3      LKBONNY2      LKBONNY3        NBHWF1  \
# count  20778.000000  20778.000000  20778.000000  20778.000000  20778.000000
# mean      44.679442     47.878493     46.441632     11.577460     58.876390
# std       31.893685     33.359502     44.204632     11.066033     41.338364
# min       -1.200000     -1.100000     -1.433660     -0.336680     -1.200000
# 25%       14.600000     16.300000      9.652405      2.501000     19.400000
# 50%       42.200000     46.559500     31.355795      7.759260     59.798500
# 75%       73.374890     77.734265     77.186723     19.035310     96.881890
# max      102.300000    109.900000    157.745000     38.684660    131.059000
#
#            SNOWNTH1      SNOWSTH1      SNOWTWN1      WATERLWF   Unnamed: 15  \
# count  20778.000000  20778.000000  20778.000000  20778.000000  20778.000000
# mean      55.925392     54.765276     43.443422     48.632761      0.797251
# std       44.017710     39.212054     32.232361     39.069051      2.959013
# min        0.000000      0.000000     -0.928820     -1.200000      0.000000
# 25%       15.100000     17.355000     10.596363     13.201000      0.000000
# 50%       47.800000     51.800000     44.138420     39.300000      0.000000
# 75%       98.800000     90.354345     73.134880     86.000000      0.000000
# max      143.300000    125.017000     96.670120    129.706000     17.900000
#
#        Average Frequency (Hz)  Median Frequency (Hz)  \
# count            20778.000000           20778.000000
# mean                50.010700              50.009851
# std                  0.039128               0.042637
# min                 49.842233              49.810001
# 25%                 49.987033              49.990002
# 50%                 50.011800              50.009998
# 75%                 50.035533              50.040001
# max                 50.167866              50.169998
#
#        Cummulative Frequency (Hz)  Difference Frequency (Hz)  \
# count                20778.000000               20778.000000
# mean                     2.382877                  -0.001477
# std                      0.231348                   0.082418
# min                      1.559982                  -0.290001
# 25%                      2.229970                  -0.059998
# 50%                      2.370018                   0.000000
# 75%                      2.520039                   0.049999
# max                      4.440033                   0.340000
#
#        Lower Throughput Ratio
# count            20778.000000
# mean                 0.278321
# std                  0.230872
# min                  0.000001
# 25%                  0.089060
# 50%                  0.223874
# 75%                  0.414948
# max                  1.000000

# %%
a = np.percentile(df, [25, 50, 75])
a
# Out:
# array([ 2.19997787, 25.4       , 50.13999939])

# %%
df.columns
# Out:
# Index(['BLUFF1', 'CLEMGPWF', 'HALLWF1', 'HALLWF2', 'HDWF1', 'HDWF2', 'HDWF3',
#        'LKBONNY2', 'LKBONNY3', 'NBHWF1', 'SNOWNTH1', 'SNOWSTH1', 'SNOWTWN1',
#        'WATERLWF', 'Unnamed: 15', 'Average Frequency (Hz)',
#        'Median Frequency (Hz)', 'Cummulative Frequency (Hz)',
#        'Difference Frequency (Hz)', 'Lower Throughput Ratio'],
#       dtype='object')

# %% [markdown]
# ##  3. Split `df` into `df_train`, `df_test` with 30% as test

# %%
df_train, df_test = train_test_split(df, test_size = 0.3, random_state = 100)
display(df_train.head())
display(df_test.head())
# Out:
#        BLUFF1  CLEMGPWF  HALLWF1  HALLWF2   HDWF1   HDWF2   HDWF3   LKBONNY2  \
# 937     9.400   3.02547   38.610   11.850  36.700   9.800  43.200   61.07637
# 12346  29.232  31.10100   65.209   51.264  67.722  73.932  82.819  134.18300
# 10428  49.889  21.18900   62.029   42.499  69.059  66.490  65.059   48.74700
# 5590    0.212   4.99700    0.000    0.000  11.387   9.490   6.195   21.27200
# 13889   6.700  -0.21611   22.420    7.750  17.200  13.200  19.700    6.45276
#
#        LKBONNY3   NBHWF1  SNOWNTH1  SNOWSTH1  SNOWTWN1  WATERLWF  Unnamed: 15  \
# 937    12.55995   42.300   113.700   102.800    0.0000    41.000          0.0
# 12346  32.60100  120.136    91.341    48.691   77.8360    50.177          0.0
# 10428  10.91600  114.801    82.251    94.841   88.2950    94.585          0.0
# 5590    7.04800    0.000    27.899    22.248   20.3280    11.187          0.0
# 13889   0.05582   20.700    16.200     8.400    8.4683     1.700          0.0
#
#        Average Frequency (Hz)  Median Frequency (Hz)  \
# 937                 49.982933              49.990002
# 12346               50.003134              50.000000
# 10428               49.962567              49.970001
# 5590                50.007200              50.000000
# 13889               50.019467              50.029999
#
#        Cummulative Frequency (Hz)  Difference Frequency (Hz)  \
# 937                      2.349968                  -0.110001
# 12346                    2.160004                   0.120003
# 10428                    2.459999                   0.080002
# 5590                     2.189980                  -0.070000
# 13889                    2.400036                   0.020000
#
#        Lower Throughput Ratio
# 937                  0.122113
# 12346                0.049341
# 10428                0.256708
# 5590                 0.148876
# 13889                0.544832
#        BLUFF1  CLEMGPWF  HALLWF1  HALLWF2   HDWF1   HDWF2   HDWF3   LKBONNY2  \
# 7303    3.500  53.44998   16.250   11.730  31.500  19.400  24.100    8.46766
# 10187  21.700  43.34200   57.858   48.602  40.973  58.417  56.314    2.32700
# 13175  39.400  23.12324   69.100   54.350  74.600  82.500  79.800  117.63667
# 9844    0.221  35.69000    9.355   20.695  20.434  16.415  18.879    7.94400
# 6565    9.400  52.72963   32.220   42.540  26.000  17.900  18.600    6.08401
#
#        LKBONNY3  NBHWF1  SNOWNTH1  SNOWSTH1  SNOWTWN1  WATERLWF  Unnamed: 15  \
# 7303    1.22808  24.600   131.500   112.600  94.54403    20.700          0.0
# 10187   0.61600  93.140    37.078    36.365  44.85200    29.789          0.0
# 13175  29.02745  96.600   105.200    85.100  72.40504    50.500          0.0
# 9844    0.95600  30.739   106.769    61.809  78.24000    14.979          0.0
# 6565    3.07021  63.100   110.000   107.600  92.90159    45.500          0.0
#
#        Average Frequency (Hz)  Median Frequency (Hz)  \
# 7303                49.931900              49.919998
# 10187               49.978000              49.970001
# 13175               50.086600              50.090000
# 9844                50.016867              50.009998
# 6565                50.033333              50.040001
#
#        Cummulative Frequency (Hz)  Difference Frequency (Hz)  \
# 7303                     2.239998                  -0.080002
# 10187                    2.669991                  -0.209999
# 13175                    2.450031                   0.090000
# 9844                     1.929989                  -0.009998
# 6565                     2.749996                   0.090000
#
#        Lower Throughput Ratio
# 7303                 0.782171
# 10187                0.276639
# 13175                0.097938
# 9844                 0.353877
# 6565                 0.281637

# %%
# Split df_train
X_train = df_train.drop('Lower Throughput Ratio',axis=1) # Features
Y_train = df_train['Lower Throughput Ratio']

# Split df_train
X_test = df_test.drop('Lower Throughput Ratio',axis=1) # Features
Y_test = df_test['Lower Throughput Ratio']

# %%
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (14544, 19) (14544,)
# (6234, 19) (6234,)

# %% [markdown]
# ## 4. Fit Regression Model

# %%
param_grid = {'max_depth':np.arange(2,10),
             'min_samples_leaf':np.arange(1,3),
             'min_samples_split':np.arange(2,5)            
             }

clf = GridSearchCV(DecisionTreeRegressor(), param_grid, cv=5)
clf.fit(X_train,Y_train)

print("best_parms:{0}\nbest_score:{1}".format(clf.best_params_, clf.best_score_))
# Out:
# best_parms:{'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 4}
# best_score:0.04847842976900411

# %%
max_d = clf.best_params_['max_depth']
min_sl = clf.best_params_['min_samples_leaf']
min_ss = clf.best_params_['min_samples_split']
max_d,min_sl,min_ss
# Out:
# (4, 1, 4)

# %%
DTR = DecisionTreeRegressor(max_depth=max_d,min_samples_leaf=min_sl,
                           min_samples_split=min_ss)
DTR.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=4, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=4, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %% [markdown]
# ## 5. Predict

# %%
Y_test_pred = DTR.predict(X_test)
mean_squared_error(Y_test, Y_test_pred)
# Out:
# 0.049638047739171284

# %%
Y_train_pred = DTR.predict(X_train)
mean_squared_error(Y_train, Y_train_pred)
# Out:
# 0.04984914322383897

# %%
with open("tree.dot", 'w') as f:
    f = tree.export_graphviz(DTR, out_file=f)
