# %% [markdown]
# # Predict Regulation Throughput Ratio with CART Decision Trees
# ## (Lower Frequency Regulation Service)

# %% [markdown]
# ## 1. Import the necessary modules and libraries

# %%
# data analysis and wrangling
import pandas as pd
import numpy as np

# visualization
import matplotlib.pyplot as plt
import pydotplus

# machine learning
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import export_graphviz
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV
from sklearn import tree

# %% [markdown]
# ## 2. Exploring and Preprocessing the Data

# %%
# read data from csv file
df = pd.read_csv("df_lower_alldata.csv").fillna(0)

# %%
df = df.drop(['Unnamed: 0'],axis=1)
df.head(5)
# Out:
#   Interval Ending (AEST)  BLUFF1  CLEMGPWF  HALLWF1  HALLWF2  HDWF1  HDWF2  \
# 0            1/1/18 0:15    14.3   2.44919    13.60    10.63   22.2   15.6
# 1            1/1/18 1:00     9.9   1.51274     8.72     7.63   19.6   17.0
# 2            1/1/18 1:15    11.0   0.79239     9.27     7.26   14.6   16.0
# 3            1/1/18 1:55     4.7   1.65681     6.49    -0.06   10.7   21.9
# 4            1/1/18 2:10     3.7   0.72035     5.34    -0.36   13.0   22.6
#
#    HDWF3  LKBONNY2  LKBONNY3           ...            SNOWNTH1  SNOWSTH1  \
# 0   16.6  32.53022  13.22982           ...                13.4       7.4
# 1   13.1  23.63865   9.43392           ...                 9.7       1.2
# 2   12.0  22.36064   5.13563           ...                 8.9       2.3
# 3   16.2  26.73126   6.47535           ...                11.4       7.3
# 4   22.0  25.91605   7.81508           ...                12.3       6.4
#
#    SNOWTWN1  WATERLWF  Unnamed: 15  Average Frequency (Hz)  \
# 0  12.43428      13.3          0.0               50.063867
# 1   6.01231       8.9          0.0               50.043700
# 2   4.41001       4.1          0.0               50.047967
# 3   8.23130       0.2          0.0               50.032533
# 4   6.92434      -0.4          0.0               50.029000
#
#    Median Frequency (Hz)  Cummulative Frequency (Hz)  \
# 0              50.070000                    2.340012
# 1              50.040001                    1.950005
# 2              50.040001                    2.269928
# 3              50.029999                    2.140041
# 4              50.029999                    2.140018
#
#    Difference Frequency (Hz)  Lower Throughput Ratio
# 0                   0.000000                0.020234
# 1                   0.010002                0.126083
# 2                   0.050003                0.090646
# 3                   0.020000                0.181213
# 4                  -0.060001                0.106281
#
# [5 rows x 21 columns]

# %%
column_names=list(df)
column_names
# Out:
# ['Interval Ending (AEST)',
#  'BLUFF1',
#  'CLEMGPWF',
#  'HALLWF1',
#  'HALLWF2',
#  'HDWF1',
#  'HDWF2',
#  'HDWF3',
#  'LKBONNY2',
#  'LKBONNY3',
#  'NBHWF1',
#  'SNOWNTH1',
#  'SNOWSTH1',
#  'SNOWTWN1',
#  'WATERLWF',
#  'Unnamed: 15',
#  'Average Frequency (Hz)',
#  'Median Frequency (Hz)',
#  'Cummulative Frequency (Hz)',
#  'Difference Frequency (Hz)',
#  'Lower Throughput Ratio']

# %%
#from sklearn import preprocessing
#scaler = preprocessing.StandardScaler()
#df_array = scaler.fit_transform(df)
#df = pd.DataFrame(df_array)
#df.columns=column_names
#df.head(5)

# %%
df.describe()
# Out:
#              BLUFF1      CLEMGPWF       HALLWF1       HALLWF2         HDWF1  \
# count  20778.000000  20778.000000  20778.000000  20778.000000  20778.000000
# mean      19.203651     23.186787     40.469118     30.710160     48.014205
# std       17.072084     18.295492     29.090983     22.213073     32.042073
# min       -0.200000     -0.648320     -0.840000     -0.600000     -1.100000
# 25%        2.700000      5.258560     13.083750      9.910000     17.312500
# 50%       14.690500     21.290000     39.225000     29.658000     48.700000
# 75%       36.275108     40.483680     68.280000     51.390000     76.400000
# max       52.962000     56.415000     90.670000     70.360000    100.800000
#
#               HDWF2         HDWF3      LKBONNY2      LKBONNY3        NBHWF1  \
# count  20778.000000  20778.000000  20778.000000  20778.000000  20778.000000
# mean      44.679442     47.878493     46.441632     11.577460     58.876390
# std       31.893685     33.359502     44.204632     11.066033     41.338364
# min       -1.200000     -1.100000     -1.433660     -0.336680     -1.200000
# 25%       14.600000     16.300000      9.652405      2.501000     19.400000
# 50%       42.200000     46.559500     31.355795      7.759260     59.798500
# 75%       73.374890     77.734265     77.186723     19.035310     96.881890
# max      102.300000    109.900000    157.745000     38.684660    131.059000
#
#            SNOWNTH1      SNOWSTH1      SNOWTWN1      WATERLWF   Unnamed: 15  \
# count  20778.000000  20778.000000  20778.000000  20778.000000  20778.000000
# mean      55.925392     54.765276     43.443422     48.632761      0.797251
# std       44.017710     39.212054     32.232361     39.069051      2.959013
# min        0.000000      0.000000     -0.928820     -1.200000      0.000000
# 25%       15.100000     17.355000     10.596363     13.201000      0.000000
# 50%       47.800000     51.800000     44.138420     39.300000      0.000000
# 75%       98.800000     90.354345     73.134880     86.000000      0.000000
# max      143.300000    125.017000     96.670120    129.706000     17.900000
#
#        Average Frequency (Hz)  Median Frequency (Hz)  \
# count            20778.000000           20778.000000
# mean                50.010700              50.009851
# std                  0.039128               0.042637
# min                 49.842233              49.810001
# 25%                 49.987033              49.990002
# 50%                 50.011800              50.009998
# 75%                 50.035533              50.040001
# max                 50.167866              50.169998
#
#        Cummulative Frequency (Hz)  Difference Frequency (Hz)  \
# count                20778.000000               20778.000000
# mean                     2.382877                  -0.001477
# std                      0.231348                   0.082418
# min                      1.559982                  -0.290001
# 25%                      2.229970                  -0.059998
# 50%                      2.370018                   0.000000
# 75%                      2.520039                   0.049999
# max                      4.440033                   0.340000
#
#        Lower Throughput Ratio
# count            20778.000000
# mean                 0.278321
# std                  0.230872
# min                  0.000001
# 25%                  0.089060
# 50%                  0.223874
# 75%                  0.414948
# max                  1.000000

# %% [markdown]
# ##  3. Split `df` into `df_train`, `df_test` with 30% as test

# %%
# If split randomly:
df_train, df_test = train_test_split(df, test_size = 0.3, random_state = 50)
# If split according to the datetime sequence:
#cut_point = round(len(df)*0.7)
#df_train = df[:cut_point]
#time_train = time[:cut_point]
#df_test = df[cut_point:]
#time_test = time[cut_point:]

display(df_train.head())
display(df_test.head())
# Out:
#       Interval Ending (AEST)  BLUFF1  CLEMGPWF  HALLWF1  HALLWF2  HDWF1  \
# 20283          10/12/18 9:10     7.8  30.97506    26.79    21.63   32.3
# 3840             2/7/18 6:25     4.1  15.41549    28.41    14.20   65.6
# 398              1/3/18 5:30     9.6  10.37304    33.76    15.17   46.4
# 19054          9/29/18 12:50     0.2  -0.36018    -0.49     0.31    2.5
# 4958           2/19/18 14:20    22.6  15.70363    35.83    40.15   18.2
#
#        HDWF2  HDWF3   LKBONNY2  LKBONNY3           ...            SNOWNTH1  \
# 20283   39.5   42.4    1.72464   2.23288           ...                44.1
# 3840    71.3   59.4   -1.16015  -0.22503           ...                25.1
# 398     26.9   36.6   21.45103   3.23768           ...                49.3
# 19054    1.3    2.4    9.91876   3.29350           ...                 5.7
# 4958    19.4   20.8  147.67801  35.16787           ...                76.8
#
#        SNOWSTH1  SNOWTWN1  WATERLWF  Unnamed: 15  Average Frequency (Hz)  \
# 20283      50.5  49.29219      37.3          5.5               50.056900
# 3840       55.9  18.78849      20.9          0.0               50.077467
# 398        14.8  29.44857      12.4          0.0               50.085667
# 19054       7.2  -0.18310      -0.2          0.0               50.033467
# 4958       90.5  69.41961      74.7          0.0               50.012967
#
#        Median Frequency (Hz)  Cummulative Frequency (Hz)  \
# 20283              50.060001                    2.450031
# 3840               50.080002                    2.500046
# 398                50.090000                    2.419987
# 19054              50.020000                    2.419987
# 4958               50.000000                    2.129974
#
#        Difference Frequency (Hz)  Lower Throughput Ratio
# 20283                   0.090000                0.239116
# 3840                    0.000000                0.328130
# 398                     0.020000                0.851117
# 19054                   0.020000                0.226209
# 4958                    0.029999                0.003490
#
# [5 rows x 21 columns]
#       Interval Ending (AEST)    BLUFF1  CLEMGPWF   HALLWF1   HALLWF2  \
# 2859           1/24/18 12:35   4.40000   6.98740   3.14000  16.15000
# 15922           8/1/18 23:25  48.68200  36.33700  88.40700  63.75600
# 13694           6/16/18 2:00  44.06906  47.39503  78.99172  59.03591
# 11438           5/14/18 5:25   0.09600   7.25500   0.80900   2.89600
# 3505            2/2/18 23:10  49.32800  53.72000  56.33800  40.87800
#
#            HDWF1      HDWF2     HDWF3  LKBONNY2  LKBONNY3  \
# 2859     0.60000    4.90000    2.1000  29.82918   6.36371
# 15922  100.00000  100.00000  109.0000  56.02400  15.30800
# 13694   84.81216   84.81216   90.6326  83.33200  11.41500
# 11438   16.95700   14.73900   22.5390   0.00000   0.00000
# 3505    19.97900   33.50800   36.7750  99.55200  20.67700
#
#                 ...            SNOWNTH1   SNOWSTH1  SNOWTWN1   WATERLWF  \
# 2859            ...              69.600   28.70000  35.78399   10.10000
# 15922           ...             132.934  105.70400  94.26500   98.47200
# 13694           ...             104.566  104.76796  76.98700  108.09393
# 11438           ...              17.544    6.84000  12.73600   14.40700
# 3505            ...             130.224  109.83500  85.87800   83.96200
#
#        Unnamed: 15  Average Frequency (Hz)  Median Frequency (Hz)  \
# 2859           0.0               50.077233              50.080002
# 15922          0.0               50.067700              50.094999
# 13694          0.0               50.018700              50.009998
# 11438          0.0               50.020766              50.020000
# 3505           0.0               50.041600              50.049999
#
#        Cummulative Frequency (Hz)  Difference Frequency (Hz)  \
# 2859                     2.440018                  -0.080002
# 15922                    2.620014                   0.200001
# 13694                    2.349979                  -0.009998
# 11438                    2.850010                  -0.009998
# 3505                     2.119995                   0.040001
#
#        Lower Throughput Ratio
# 2859                 0.608133
# 15922                0.020814
# 13694                0.038165
# 11438                0.199270
# 3505                 0.150120
#
# [5 rows x 21 columns]

# %%
time_train = df_train['Interval Ending (AEST)']
time_test = df_test['Interval Ending (AEST)']
df_train = df_train.drop(['Interval Ending (AEST)'],axis=1)
df_test = df_test.drop(['Interval Ending (AEST)'],axis=1)

# %%
# Split df_train
X_train = df_train.drop('Lower Throughput Ratio',axis=1) # Features
Y_train = df_train['Lower Throughput Ratio']

# Split df_train
X_test = df_test.drop('Lower Throughput Ratio',axis=1) # Features
Y_test = df_test['Lower Throughput Ratio']

# %%
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (14544, 19) (14544,)
# (6234, 19) (6234,)

# %% [markdown]
# ## 4. Fit Regression Model

# %%
param_grid = {'max_depth':np.arange(1,8),
             'min_samples_leaf':np.arange(1,3),
             'min_samples_split':np.arange(2,4)            
             }

clf = GridSearchCV(DecisionTreeRegressor(), param_grid, cv=5)
clf.fit(X_train,Y_train)

print("best_parms:{0}\nbest_score:{1}".format(clf.best_params_, clf.best_score_))
# Out:
# best_parms:{'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2}
# best_score:0.04524479418703847

# %%
max_d = clf.best_params_['max_depth']
min_sl = clf.best_params_['min_samples_leaf']
min_ss = clf.best_params_['min_samples_split']
max_d,min_sl,min_ss
# Out:
# (5, 2, 2)

# %%
mse_train,mse_test = [],[]
m_d = range(1,8)
for md in m_d:
    DTR = DecisionTreeRegressor(max_depth=md,min_samples_leaf=min_sl,
                           min_samples_split=min_ss)
    DTR.fit(X_train,Y_train)
    Y_train_pred = DTR.predict(X_train)
    mse_train.append(mean_squared_error(Y_train, Y_train_pred))
    Y_test_pred = DTR.predict(X_test)
    mse_test.append(mean_squared_error(Y_test, Y_test_pred))
plt.plot(m_d,mse_train,'o-',label='MSE_train')
plt.plot(m_d,mse_test,'o-',label='MSE_test')
plt.legend()
plt.title('MSE of Different Max Depths')
plt.xlabel('Max Depth')
plt.ylabel('MSE')
# Out:
# Text(0, 0.5, 'MSE')

# %%
md_chosen = m_d[mse_test.index(min(mse_test))]
md_chosen
# Out:
# 5

# %%
DTR = DecisionTreeRegressor(max_depth=md_chosen,min_samples_leaf=min_sl,
                           min_samples_split=min_ss)
DTR.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=5, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=2,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %% [markdown]
# ## 5. Predict

# %%
Y_train_pred = DTR.predict(X_train)
mean_squared_error(Y_train, Y_train_pred)
# Out:
# 0.04818928778158586

# %%
Y_test_pred = DTR.predict(X_test)
mean_squared_error(Y_test, Y_test_pred)
# Out:
# 0.050708768534893436

# %%
plt.plot(time_train[:50],Y_train[:50],label='Y_train')
plt.plot(time_train[:50],Y_train_pred[:50],label='Y_train_pred')
plt.legend()
plt.title('Y_train & Y_train_pred')
plt.xlabel('time')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
plt.plot(time_test[:50],Y_test[:50],label='Y_test')
plt.plot(time_test[:50],Y_test_pred[:50],label='Y_test_pred')
plt.legend()
plt.title('Y_test & Y_test_pred')
plt.xlabel('time')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
dot_data = tree.export_graphviz(DTR,out_file=None)
graph = pydotplus.graph_from_dot_data(dot_data) 
graph.write_jpg("DecisionTree_lower.jpg")
# Out:
# True
